# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=3,include_bias=False)   #Here we set the different values of the degree to set the best curve or either the accuracy of the model
X_trf = poly.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-38ee1cc1b129> in <cell line: 3>()
#       1 from sklearn.preprocessing import PolynomialFeatures
#       2 poly = PolynomialFeatures(degree=3,include_bias=False)
# ----> 3 X_trf = poly.fit_transform(X)
#
# NameError: name 'X' is not defined

# %%
clf1 = LogisticRegression()
np.mean(cross_val_score(clf1,X_trf,y,scoring='accuracy',cv=10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7401a0ddd510> in <cell line: 1>()
# ----> 1 clf1 = LogisticRegression()
#       2 np.mean(cross_val_score(clf1,X_trf,y,scoring='accuracy',cv=10))
#
# NameError: name 'LogisticRegression' is not defined

# %%
plot_decision_boundary(X,y)
