# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/data_science_job.csv')

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline  experience company_size    company_type  training_hours  \
# 0             STEM        20.0          NaN             NaN            36.0
# 1             STEM        15.0        50-99         Pvt Ltd            47.0
# ...

# %%
df.isnull().mean()*100  #calculating the percentage of missing values in each columns
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     2.500261
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# training_hours             3.998330
# target                     0.000000
# dtype: float64

# %%
 cols = [var for var in df.columns if df[var].isnull().mean() < 0.05 and df[var].isnull().mean() > 0]
cols     # exteracting the data with the perccent of missing values less than 5 percent
# Out:
# ['city_development_index',
#  'enrolled_university',
#  'education_level',
#  'experience',
#  'training_hours']

# %%
df[cols].sample(5)
# Out:
#        city_development_index enrolled_university education_level  experience  \
# 10536                   0.920       no_enrollment        Graduate         8.0
# 84                      0.796    Part time course         Masters         4.0
# 12733                   0.624       no_enrollment         Masters        11.0
# 7793                    0.743       no_enrollment             Phd        13.0
# 5880                    0.624    Full time course     High School         3.0
#
#        training_hours
# 10536            17.0
# 84               74.0
# 12733            10.0
# 7793             23.0
# 5880             53.0

# %%
df.shape
# Out:
# (19158, 13)

# %%
 df_new=df[cols].dropna()

# %%
df_new.shape
# Out:
# (17182, 5)

# %%
len(df[cols].dropna()) / len(df)  #percentage of data left after removing the null columns

# so the above len function is used to calculate the percentage of any operation let say we are finding ther percnentage of the any columns value counts after any change say cca so we write  ->
# new_df['education_level'].value_counts() / len(new_df)
# Out:
# 0.8968577095730244

# %% [markdown]
# **always check the the data in histogram before removing the missing value and after removing so that there is almost same diagram **
