# %%
import matplotlib.pyplot as plt
import numpy as  np
x=[1,2,3,4]
y=[1,2,3,4]
plt.plot(x,y)

# %%
plt.plot(x,y,'o')

# %%
plt.grid()
plt.xlabel('IIIT BHUBANESWAR')
plt.ylabel('KARTIK')
plt.plot(x,y,marker='*',ms=30,mec='black',mfc='yellow',ls='dotted',color='red')

# %%
plt.grid(axis='y')

# %%
x=[1,2,3,4]
y=[1,2,3,4]
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.scatter(x,y)

# %%
plt.hist(x)
# Out:
# (array([1., 0., 0., 1., 0., 0., 1., 0., 0., 1.]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f61464f9300>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, ''),
#   Text(0.33991867422268784, 1.0461621742897658, ''),
#   Text(-1.0461621902025062, 0.3399186252483017, ''),
#   Text(0.3399188211458418, -1.0461621265515308, '')])

# %%
plt.pie(y)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f614640d360>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, ''),
#   Text(0.33991867422268784, 1.0461621742897658, ''),
#   Text(-1.0461621902025062, 0.3399186252483017, ''),
#   Text(0.3399188211458418, -1.0461621265515308, '')])
