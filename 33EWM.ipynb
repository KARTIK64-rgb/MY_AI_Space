# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/DailyDelhiClimate.csv')

# %%
df
# Out:
#             date   meantemp   humidity  wind_speed  meanpressure
# 0     2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1     2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2     2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3     2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4     2013-01-05   6.000000  86.833333    3.700000   1016.500000
# ...          ...        ...        ...         ...           ...
# 1571  2017-04-20  34.500000  27.500000    5.562500    998.625000
# 1572  2017-04-21  34.250000  39.375000    6.962500    999.875000
# 1573  2017-04-22  32.900000  40.900000    8.890000   1001.600000
# 1574  2017-04-23  32.875000  27.500000    9.962500   1002.125000
# 1575  2017-04-24  32.000000  27.142857   12.157143   1004.142857
#
# [1576 rows x 5 columns]

# %%
df=df[['date','meantemp']]
df
# Out:
#             date   meantemp
# 0     2013-01-01  10.000000
# 1     2013-01-02   7.400000
# 2     2013-01-03   7.166667
# 3     2013-01-04   8.666667
# 4     2013-01-05   6.000000
# ...          ...        ...
# 1571  2017-04-20  34.500000
# 1572  2017-04-21  34.250000
# 1573  2017-04-22  32.900000
# 1574  2017-04-23  32.875000
# 1575  2017-04-24  32.000000
#
# [1576 rows x 2 columns]

# %%
plt.scatter(df['date'],df['meantemp'],color ='red')

# %% [markdown]
# adding new column with the values of exponential weighted moving average

# %%
x1=df['meantemp'].ewm(alpha=0.9).mean()  # creatin new column and adding to the original dataframe
df['ewm']=x1
df
# Out:
# <ipython-input-8-4d95c3eb1373>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ewm']=x1
#             date   meantemp        ewm
# 0     2013-01-01  10.000000  10.000000
# 1     2013-01-02   7.400000   7.636364
# 2     2013-01-03   7.166667   7.213213
# 3     2013-01-04   8.666667   8.521452
# 4     2013-01-05   6.000000   6.252123
# ...          ...        ...        ...
# 1571  2017-04-20  34.500000  34.403401
# 1572  2017-04-21  34.250000  34.265340
# 1573  2017-04-22  32.900000  33.036534
# 1574  2017-04-23  32.875000  32.891153
# 1575  2017-04-24  32.000000  32.089115
#
# [1576 rows x 3 columns]

# %%
plt.scatter(df['date'],df['meantemp'],color ='red')
plt.plot(df['date'],x1,color='black')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
